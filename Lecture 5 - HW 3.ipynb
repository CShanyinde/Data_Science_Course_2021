# %% [markdown]
# **Fertility Diagnosis Homework**

# %% [markdown]
# https://archive.ics.uci.edu/ml/datasets/Fertility#
#
# **Summary**
# 100 volunteers provide a semen sample analyzed according to the WHO 2010 criteria. Sperm concentration are related to socio-demographic data, environmental factors, health status, and life habits
#
# **Attribute Information:**
# 1. **Season** in which the analysis was performed. 1) winter, 2) spring, 3) Summer, 4) fall. (-1, -0.33, 0.33, 1)
# 2. **Age** at the time of analysis. 18-36 (0, 1)
# 3. **Childish diseases** (ie , chicken pox, measles, mumps, polio) 1) yes, 2) no. (0, 1)
# 4. **Accident or serious trauma** 1) yes, 2) no. (0, 1)
# 5. **Surgical intervention** 1) yes, 2) no. (0, 1)
# 6. **High fevers** in the last year 1) less than three months ago, 2) more than three months ago, 3) no. (-1, 0, 1)
# 7. **Frequency of alcohol consumption** 1) several times a day, 2) every day, 3) several times a week, 4) once a week, 5) hardly ever or never (0, 1)
# 8. **Smoking habit** 1) never, 2) occasional 3) daily. (-1, 0, 1)
# 9. **Number of hours spent sitting** per day ene-16 (0, 1)
# 10. **Output:** Diagnosis normal (N), altered (O)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn import datasets
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading the file
data=pd.read_excel("Fertility_Diagnosis.xlsx")
data.shape
# Out:
# (100, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Season                 100 non-null    float64
#  1   Age                    100 non-null    float64
#  2   Childish_Disease       100 non-null    int64
#  3   Accident               100 non-null    int64
#  4   Surgical_Intervention  100 non-null    int64
#  5   High_Fever             100 non-null    int64
#  6   Alcohol_Consumption    100 non-null    float64
#  7   Smoking                100 non-null    int64
#  8   Sitting                100 non-null    float64
#  9   Diagnosis              100 non-null    object
#  10  Diagnosis_Grade        100 non-null    int64
# dtypes: float64(4), int64(6), object(1)
# memory usage: 8.7+ KB

# %%
data.describe()
# Out:
#            Season         Age  Childish_Disease    Accident  \
# count  100.000000  100.000000        100.000000  100.000000
# mean    -0.078900    0.669000          0.870000    0.440000
# std      0.796725    0.121319          0.337998    0.498888
# min     -1.000000    0.500000          0.000000    0.000000
# 25%     -1.000000    0.560000          1.000000    0.000000
# 50%     -0.330000    0.670000          1.000000    0.000000
# 75%      1.000000    0.750000          1.000000    1.000000
# max      1.000000    1.000000          1.000000    1.000000
#
#        Surgical_Intervention  High_Fever  Alcohol_Consumption     Smoking  \
# count             100.000000  100.000000           100.000000  100.000000
# mean                0.510000    0.190000             0.832000   -0.350000
# std                 0.502418    0.580752             0.167501    0.808728
# min                 0.000000   -1.000000             0.200000   -1.000000
# ...

# %%
data.head()
# Out:
#    Season   Age  Childish_Disease  Accident  Surgical_Intervention  \
# 0   -0.33  0.69                 0         1                      1
# 1   -0.33  0.94                 1         0                      1
# 2   -0.33  0.50                 1         0                      0
# 3   -0.33  0.75                 0         1                      1
# 4   -0.33  0.67                 1         1                      0
#
#    High_Fever  Alcohol_Consumption  Smoking  Sitting Diagnosis  \
# 0           0                  0.8        0     0.88         N
# 1           0                  0.8        1     0.31         O
# 2           0                  1.0       -1     0.50         N
# 3           0                  1.0       -1     0.38         N
# 4           0                  0.8       -1     0.50         O
#
#    Diagnosis_Grade
# 0                0
# 1                1
# 2                0
# 3                0
# 4                1

# %%
#Mean age of participants
average=data["Age"].mean()
average*36
# Out:
# 24.084000000000007

# %%
#Is there a correlation between the data?
data.corr().round(decimals=2)
# Out:
#                        Season   Age  Childish_Disease  Accident  \
# Season                   1.00  0.07             -0.18     -0.10
# Age                      0.07  1.00              0.08      0.22
# Childish_Disease        -0.18  0.08              1.00      0.16
# Accident                -0.10  0.22              0.16      1.00
# Surgical_Intervention   -0.01  0.27             -0.14      0.10
# High_Fever              -0.22  0.12              0.08     -0.08
# Alcohol_Consumption     -0.04 -0.25              0.04     -0.24
# Smoking                 -0.03  0.07              0.09      0.11
# Sitting                 -0.02 -0.44             -0.15      0.01
# Diagnosis_Grade          0.19  0.12             -0.04     -0.14
#
#                        Surgical_Intervention  High_Fever  Alcohol_Consumption  \
# Season                                 -0.01       -0.22                -0.04
# Age                                     0.27        0.12                -0.25
# ...

# %%
#Assign values
#X=(data.Season, data.Age, data.Childish_Disease, data.Accident, data.Surgical_Intervention, data.High_Fever, data.Alcohol_Consumption, data.Smoking, data.Sitting)
X=(data.Alcohol_Consumption, data.Smoking)
y=data.Diagnosis_Grade

# %%
#print("Alcohol Consumption shape is:", X.shape)
print("Diagnosis Grade shape is:", y.shape)
print("Data different groupss:", len(np.unique(y)))
# Out:
# Diagnosis Grade shape is: (100,)
# Data different groupss: 2

# %%
#Re-usable code
def plot_clusters(X, idx1, idx2, y=None,):
    plt.scatter(X[:, idx1], X[:, idx2], c=y)
    plt.show()
    
def plot_centroids(centroids, weights=None, circle_color='w', cross_color='k'):
    if weights is not None:
        centroids = centroids[weights>weights.max() / 10]
        
    plt.scatter(centroids[:, idx1], centroids[:, idx2], marker='o', s=30, Linewidths=8, color=circle_color, zorder=10, alpha=0.9)
    plt.scatter(centroids[:, idx1], centroids[:, idx2], marker='x', s=50, Linewidths=50, color=cross_color, zorder=11, alpha=1)
    
def plot_clusters_labels(X, y=None):
    plt.scatter(X[:, idx1], X[:, idx2], c=y_pred)
    plot_centroids(kmeans,cluster_centres_)
    plt.show()

# %%
#Feature selection
idx1=0
idx2=1

# %%
#clustering the data
k=2 #number of clusters

#Fitting the model
kmeans=KMeans(n_clusters=k, random_state=42)

# %%
#Creating the predictions
y_pred = kmeans.fit_predict((X))
plot_clusters((X, idx1, idx2, y_pred))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-eed3fa1f5651> in <module>
#       1 #Creating the predictions
#       2 y_pred = kmeans.fit_predict((X))
# ----> 3 plot_clusters((X, idx1, idx2, y_pred))
#
# TypeError: plot_clusters() missing 2 required positional arguments: 'idx1' and 'idx2'
